# %%
12
# Out:
# 12

# %%
12.12
# Out:
# 12.12

# %%
"sdkjfhkdshfkjhdf"
# Out:
# 'sdkjfhkdshfkjhdf'

# %%
'skjfhdskjhfsdhf'
# Out:
# 'skjfhdskjhfsdhf'

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %% [markdown]
# Without Print Statement

# %%
"Himanshu"
"present"
"him123"
9
3
2024
# Out:
# 2024

# %% [markdown]
# With Print Statement

# %%
print("Himanshu")
print("present")
print("him123")
print(9)
print(3)
print(2024)
# Out:
# Himanshu
# present
# him123
# 9
# 3
# 2024

# %% [markdown]
# # Using Variables

# %% [markdown]
# 1. It cannot start with a number
# 2. It should not have a space
# 3. it should not be python keyword
# 4. Only underscore(_) is allowed
# 5. Anything (including variables) is case sensitive

# %%
my name = "Himanshu"
# Out:
#   File "C:\Users\sandi\AppData\Local\Temp/ipykernel_22796/3953700131.py", line 1
#     my name = "Himanshu"
#        ^
# SyntaxError: invalid syntax

# %%
my_name = "Himanshu"

# %%
my@name = "Himanshu"
# Out:
#   File "C:\Users\sandi\AppData\Local\Temp/ipykernel_22796/1241863799.py", line 1
#     my@name = "Himanshu"
#     ^
# SyntaxError: cannot assign to operator

# %%
my-name = "Himanshu"
# Out:
#   File "C:\Users\sandi\AppData\Local\Temp/ipykernel_22796/2242856887.py", line 1
#     my-name = "Himanshu"
#     ^
# SyntaxError: cannot assign to operator

# %%
name = "Himanshu"
attendance = "present"
userid = "him123"
day = 9
month = 3
year = 2024

# %%
#variable names don't require double quotes
print(name)
# Out:
# Himanshu

# %%
print(Name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22796/2644917711.py in <module>
# ----> 1 print(Name)
#
# NameError: name 'Name' is not defined

# %%
print("name")
# Out:
# name

# %%
print(attendance)
print(day)
print(year)
# Out:
# present
# 9
# 2024

# %%
name
# Out:
# 'Himanshu'

# %%
name
attendance
# Out:
# 'present'

# %%
year
# Out:
# 2024

# %% [markdown]
# Python Data Types

# %%
height = 6.1

# %%
print(type(name))
print(type(attendance))
print(type(day))
print(type(year))
print(type(height))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'float'>

# %%
age = 10

# %%
name = "Biswarup"

# %%
print(name)
# Out:
# Biswarup

# %%
print(name, attendance, day, month, year)
# Out:
# Biswarup present 9 3 2024

# %%
#F-Strings (Formatted Strings)
print(f"{name} was {attendance} on {day} - {month} - {year}")
# Out:
# Biswarup was present on 9 - 3 - 2024

# %% [markdown]
# # Unpacking

# %%
name, attendance, day, month, year = "Tiwin", "present", 10, 3, 2024

# %%
print(f"{name} was {attendance} on {day} - {month} - {year}")
# Out:
# Tiwin was present on 10 - 3 - 2024

# %%
print(name)
print(name)
print(f"This is a problematic line -----------{name}")
# Out:
# Tiwin
# Tiwin
# This is a problematic line -----------Tiwin

# %% [markdown]
# ## Assignment Operators

# %%
name = "Aditya"
marks = 60

# %%
#Short Hand Notation
marks += 5
# marks = marks + 5

# %%
marks
# Out:
# 65

# %%
marks -= 5
print(marks)
# Out:
# 60

# %%
marks *= 5
print(marks)
# Out:
# 300

# %%
marks /= 5
print(marks)
# Out:
# 60.0

# %%
marks = 61
marks %= 5
print(marks)
# Out:
# 1

# %%
marks = 61
marks **= 5
print(marks)
# Out:
# 844596301

# %%
#Floor Division
63//5 #This is not rounding off
# Out:
# 12

# %% [markdown]
# # Type Casting

# %% [markdown]
# Conversion of one data type to another data type

# %%
phone_number = 8888888888
type(phone_number)
# Out:
# int

# %%
phone_number_str = str(phone_number)
type(phone_number_str)
# Out:
# str

# %%
phone_number = str(8888888888)
type(phone_number)
# Out:
# str

# %%
age = "25"
type(age)
# Out:
# str

# %%
a = int(age)
type(a)
# Out:
# int

# %%
float(a)
# Out:
# 25.0

# %%
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22796/1879335602.py in <module>
# ----> 1 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Aditya'

# %%
name = input("Enter the Name")
age = input("Enter the Age")
height = input("Enter the Height")
# Out:
# Enter the NameHimanshu
# Enter the Age34
# Enter the Height5.8

# %%
print(name, age, height)
# Out:
# Himanshu 34 5.8

# %%
type(age)
# Out:
# str

# %%
name = input("Enter the Name")
age = int(input("Enter the Age"))
height = float(input("Enter the Height"))
# Out:
# Enter the NameHimanshu
# Enter the Age34
# Enter the Height5.8

# %%
type(age)
# Out:
# int

# %%
while(True):
    print("a")
# Out:
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# ...

# %%
print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9320/2122694447.py in <module>
# ----> 1 print(name)
#
# NameError: name 'name' is not defined

# %% [markdown]
# # Himanshu
